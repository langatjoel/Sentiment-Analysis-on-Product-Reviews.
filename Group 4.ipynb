# %%
#Group 4 Introduction
#Group Members: 1.Natasha Gicheha 2.Mercy Muthoni 3.Mary Edna 4.Isaac Mbatha 5.Joel Kipruto 6.Henry Modi 7.Karina Murage 8.Sydney Ndolo

# %%
#Natasha Gicheha
#Part B: Access Dictionary Data
#1. Print the full dictionary
student_records={
    1: {"name":"Emily", "age":17, "grade":"A", "email":"emily@gmail.com"},
    2: {"name":"Justin", "age" :18, "grade":"B", "email":"justin@gmail.com"},
    3: {"name":"Kady", "age":19, "grade":"A", "email":"justin@gmail.com" },
    4: {"name":"Peter", "age":23, "grade":"B","email":"justin@gmail.com"},
    5: {"name":"Henry", "age":24, "grade":"A","email":"justin@gmail.com"},
    6: {"name":"Paul", "age":19,"grade":"B","email":"justin@gmail.com"},
    7: {"name":"Lydiah", "age":18,"grade":"B","email":"justin@gmail.com"},
    8: {"name":"Semenyo", "age":21,"grade":"A","email":"justin@gmail.com"},
    9: {"name":"Erling", "age": 20,"grade":"A-","email":"justin@gmail.com"},
    10:{"name":"Haaland", "age": 19,"grade":"A","email":"justin@gmail.com"},
}

# %%
#Name: Natasha Gicheha
#Part B: Access Dictionary Data
#1. Print the full dictionary
import pprint #To clearly see all the students
pprint.pprint(student_records)#All information on the students is displayed
# Out:
# {1: {'age': 17, 'email': 'emily@gmail.com', 'grade': 'A', 'name': 'Emily'},
#  2: {'age': 18, 'email': 'justin@gmail.com', 'grade': 'B', 'name': 'Justin'},
#  3: {'age': 19, 'email': 'justin@gmail.com', 'grade': 'A', 'name': 'Kady'},
#  4: {'age': 23, 'email': 'justin@gmail.com', 'grade': 'B', 'name': 'Peter'},
#  5: {'age': 24, 'email': 'justin@gmail.com', 'grade': 'A', 'name': 'Henry'},
#  6: {'age': 19, 'email': 'justin@gmail.com', 'grade': 'B', 'name': 'Paul'},
#  7: {'age': 18, 'email': 'justin@gmail.com', 'grade': 'B', 'name': 'Lydiah'},
#  8: {'age': 21, 'email': 'justin@gmail.com', 'grade': 'A', 'name': 'Semenyo'},
#  9: {'age': 20, 'email': 'justin@gmail.com', 'grade': 'A-', 'name': 'Erling'},
#  10: {'age': 19, 'email': 'justin@gmail.com', 'grade': 'A', 'name': 'Haaland'}}

# %%
#Name: Natasha Gicheha
#2. Print the name of a random student
import random
any_name=random.choice(student_records)
print(any_name["name"]) #Student 8: Semenyo was selected without being specified
# Out:
# Semenyo
