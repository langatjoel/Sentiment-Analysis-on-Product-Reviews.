# %%
#Load dataset
import pandas as pd
a=pd.read_excel(r"C:\Users\T2Gic\OneDrive\Desktop\DSA Intro to Programming\Copy of amazon reviews(1).xlsx")

# %%
#Check for missing values
print(a.isnull().sum())
# Out:
# review_id            767
# product_category     771
# product_name         774
# user_id              774
# review_title         768
# review_text          771
# rating               768
# verified_purchase    779
# helpful_votes        766
# sentiment            769
# dtype: int64

# %%
#Total number of missing values
import pandas as pd
total_missing = a.isnull().sum().sum()
print("Total missing values:", total_missing)
# Out:
# Total missing values: 7707
